# %%
import pandas as pd

# %%
df=pd.read_csv("sales_table.csv")

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment   Sales  Profit  \
# 0       1001         furniture       tables      consumer    909.0  2537.0
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.0  2516.0
# 2       1003         furniture       tables     corporate   9435.0  -144.0
# 3       1004    office supplies      storage     consumer    988.0  -117.0
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.0  1798.0
# 5       1006         furniture       tables     corporate   9428.0  1218.0
# 6       1007    office supplies      storage  HOME OFFICE      NaN  2815.0
# 7       1008          FURNITURE       CHAIRS    corporate   7424.0   893.0
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.0   -82.0
# 9       1010    office supplies      storage     consumer   6381.0  2971.0
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.0  2488.0
# ...

# %%
df.head()
# Out:
#    Order ID          Category Sub-Category       Segment   Sales  Profit  \
# 0      1001        furniture       tables      consumer    909.0  2537.0
# 1      1002         FURNITURE       CHAIRS     CORPORATE  2786.0  2516.0
# 2      1003        furniture       tables     corporate   9435.0  -144.0
# 3      1004   office supplies      storage     consumer    988.0  -117.0
# 4      1005         FURNITURE       CHAIRS  HOME OFFICE    934.0  1798.0
#
#    Quantity
# 0       9.0
# 1       4.0
# 2      19.0
# 3       NaN
# 4       7.0

# %%
df.tail()
# Out:
#     Order ID           Category Sub-Category      Segment   Sales  Profit  \
# 45      1046         furniture       tables    corporate   1464.0   437.0
# 46      1047   office supplies       binders  home office  1660.0  1605.0
# 47      1048         technology      phones    corporate   8453.0   377.0
# 48      1049          FURNITURE       CHAIRS   corporate   9855.0  1860.0
# 49      1050          FURNITURE       CHAIRS     Consumer  7169.0   279.0
#
#     Quantity
# 45       3.0
# 46       NaN
# 47      18.0
# 48      16.0
# 49       4.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      50 non-null     int64
#  1   Category      50 non-null     str
#  2   Sub-Category  50 non-null     str
#  3   Segment       50 non-null     str
#  4   Sales         47 non-null     float64
#  5   Profit        47 non-null     float64
#  6   Quantity      47 non-null     float64
# dtypes: float64(3), int64(1), str(3)
# memory usage: 4.3 KB

# %%
df.describe()
# Out:
#          Order ID        Sales       Profit   Quantity
# count    50.00000    47.000000    47.000000  47.000000
# mean   1025.50000  5351.063830  1139.744681  10.978723
# std      14.57738  2962.622431  1145.804435   5.612445
# min    1001.00000   819.000000  -498.000000   1.000000
# 25%    1013.25000  2684.500000   -23.500000   7.000000
# 50%    1025.50000  6014.000000  1143.000000  11.000000
# 75%    1037.75000  7726.000000  2229.500000  16.000000
# max    1050.00000  9855.000000  2971.000000  20.000000

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Category        0
# Sub-Category    0
# Segment         0
# Sales           3
# Profit          3
# Quantity        3
# dtype: int64

# %%
df["Sales"].sum()
# Out:
# np.float64(251500.0)

# %%
df["Sales"].mean()
# Out:
# np.float64(5351.063829787234)

# %%
df["Sales"]=df["Sales"].fillna(df["Sales"].mean())

# %%
df["Quantity"].mean()
# Out:
# np.float64(5351.063829787234)

# %%
df["Quantity"]=df["Sales"].fillna(df["Sales"].mean())

# %%
df["Sales"].mean()
# Out:
# np.float64(5351.063829787234)

# %%
df["Sales"].mean()
df["Sales"].median()
df["Sales"].mode()
# Out:
# 0    5351.06383
# Name: Sales, dtype: float64

# %%
df["Profit"].mean()
df["Profit"].median()
df["Profit"].mode()
# Out:
# 0     -498.0
# 1     -487.0
# 2     -471.0
# 3     -414.0
# 4     -178.0
# 5     -144.0
# 6     -117.0
# 7      -87.0
# 8      -82.0
# 9      -65.0
# 10     -44.0
# 11     -42.0
# 12      -5.0
# 13     126.0
# 14     166.0
# 15     279.0
# 16     377.0
# 17     437.0
# 18     486.0
# 19     510.0
# 20     529.0
# 21     605.0
# 22     893.0
# 23    1143.0
# 24    1218.0
# 25    1587.0
# 26    1605.0
# 27    1661.0
# 28    1687.0
# 29    1798.0
# 30    1860.0
# 31    1864.0
# 32    1890.0
# 33    2202.0
# 34    2208.0
# 35    2251.0
# 36    2292.0
# 37    2374.0
# 38    2440.0
# 39    2488.0
# 40    2516.0
# 41    2537.0
# 42    2593.0
# 43    2815.0
# 44    2842.0
# 45    2952.0
# 46    2971.0
# Name: Profit, dtype: float64
